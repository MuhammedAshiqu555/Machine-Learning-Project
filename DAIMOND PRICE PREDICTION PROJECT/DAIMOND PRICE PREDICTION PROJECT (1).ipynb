# %% [markdown]
# ### <center> DAIMOND PRICE PREDICTION

# %% [markdown]
# ![daimond-2.webp](attachment:daimond-2.webp)

# %% [markdown]
#    ### ABOUT
# ####  These dataset contain 10 features in which 'Price(in US dollars)' is dependent feature. The goal is we have to predict the price of Diamond using different Regression Algorithms

# %% [markdown]
# #### importing libraries

# %%
# !pip install klib
# Out:
# Requirement already satisfied: klib in d:\anaconda\lib\site-packages (1.3.2)
# Requirement already satisfied: jinja2>=3.1.0 in d:\anaconda\lib\site-packages (from klib) (3.1.4)
# Requirement already satisfied: matplotlib>=3.6.0 in d:\anaconda\lib\site-packages (from klib) (3.7.5)
# Requirement already satisfied: numpy>=1.26.0 in d:\anaconda\lib\site-packages (from klib) (1.26.4)
# Requirement already satisfied: pandas<3.0,>=1.4 in d:\anaconda\lib\site-packages (from klib) (2.1.4)
# Requirement already satisfied: plotly>=5.11.0 in d:\anaconda\lib\site-packages (from klib) (5.24.1)
# Requirement already satisfied: scipy>=1.10.0 in d:\anaconda\lib\site-packages (from klib) (1.11.4)
# Requirement already satisfied: screeninfo>=0.8.1 in d:\anaconda\lib\site-packages (from klib) (0.8.1)
# Requirement already satisfied: seaborn>=0.12.0 in d:\anaconda\lib\site-packages (from klib) (0.13.2)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda\lib\site-packages (from jinja2>=3.1.0->klib) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib>=3.6.0->klib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\lib\site-packages (from matplotlib>=3.6.0->klib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\lib\site-packages (from matplotlib>=3.6.0->klib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib>=3.6.0->klib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\lib\site-packages (from matplotlib>=3.6.0->klib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in d:\anaconda\lib\site-packages (from matplotlib>=3.6.0->klib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda\lib\site-packages (from matplotlib>=3.6.0->klib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\lib\site-packages (from matplotlib>=3.6.0->klib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\lib\site-packages (from pandas<3.0,>=1.4->klib) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in d:\anaconda\lib\site-packages (from pandas<3.0,>=1.4->klib) (2023.3)
# Requirement already satisfied: tenacity>=6.2.0 in d:\anaconda\lib\site-packages (from plotly>=5.11.0->klib) (8.2.3)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.6.0->klib) (1.16.0)

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import klib as k
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.linear_model import Lasso,LinearRegression,LogisticRegression,Ridge
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import LinearSVR
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv(r"C:\Users\vkram\Downloads\cubic_zirconia.csv")
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table     x     y  \
# 0               1   0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29
# 1               2   0.33    Premium     G      IF   60.8   58.0  4.42  4.46
# 2               3   0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12
# 3               4   0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80
# 4               5   0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43
# ...           ...    ...        ...   ...     ...    ...    ...   ...   ...
# 26962       26963   1.11    Premium     G     SI1   62.3   58.0  6.61  6.52
# 26963       26964   0.33      Ideal     H      IF   61.9   55.0  4.44  4.42
# 26964       26965   0.51    Premium     E     VS2   61.7   58.0  5.12  5.15
# 26965       26966   0.27  Very Good     F    VVS2   61.8   56.0  4.19  4.20
# 26966       26967   1.25    Premium     J     SI1   62.0   58.0  6.90  6.88
#
#           z  price
# 0      2.66    499
# 1      2.70    984
# 2      3.78   6289
# 3      2.96   1082
# 4      2.65    779
# ...     ...    ...
# 26962  4.09   5408
# 26963  2.74   1114
# 26964  3.17   1656
# 26965  2.60    682
# 26966  4.27   5166
#
# [26967 rows x 11 columns]

# %% [markdown]
# ###  EDA

# %%
df.drop(columns="Unnamed: 0",inplace=True)

# %%
df['cut'] = df['cut'].str.replace('^b','')

# %%
df['clarity'] = df['clarity'].str.replace('^b','')
df['color'] = df['color'].str.replace('^b','')

# %%
df
# Out:
#        carat        cut color clarity  depth  table     x     y     z  price
# 0       0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66    499
# 1       0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70    984
# 2       0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78   6289
# 3       0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96   1082
# 4       0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65    779
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 26962   1.11    Premium     G     SI1   62.3   58.0  6.61  6.52  4.09   5408
# 26963   0.33      Ideal     H      IF   61.9   55.0  4.44  4.42  2.74   1114
# 26964   0.51    Premium     E     VS2   61.7   58.0  5.12  5.15  3.17   1656
# 26965   0.27  Very Good     F    VVS2   61.8   56.0  4.19  4.20  2.60    682
# 26966   1.25    Premium     J     SI1   62.0   58.0  6.90  6.88  4.27   5166
#
# [26967 rows x 10 columns]

# %%
df.shape
# Out:
# (26967, 10)

# %%
df.isnull().mean()*100
# Out:
# carat      0.00000
# cut        0.00000
# color      0.00000
# clarity    0.00000
# depth      2.58464
# table      0.00000
# x          0.00000
# y          0.00000
# z          0.00000
# price      0.00000
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# 34

# %%
df.drop_duplicates()
# Out:
#        carat        cut color clarity  depth  table     x     y     z  price
# 0       0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66    499
# 1       0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70    984
# 2       0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78   6289
# 3       0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96   1082
# 4       0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65    779
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 26962   1.11    Premium     G     SI1   62.3   58.0  6.61  6.52  4.09   5408
# 26963   0.33      Ideal     H      IF   61.9   55.0  4.44  4.42  2.74   1114
# 26964   0.51    Premium     E     VS2   61.7   58.0  5.12  5.15  3.17   1656
# 26965   0.27  Very Good     F    VVS2   61.8   56.0  4.19  4.20  2.60    682
# 26966   1.25    Premium     J     SI1   62.0   58.0  6.90  6.88  4.27   5166
#
# [26933 rows x 10 columns]

# %%
df.describe().T
# Out:
#          count         mean          std    min     25%      50%      75%  \
# carat  26967.0     0.798375     0.477745    0.2    0.40     0.70     1.05
# depth  26270.0    61.745147     1.412860   50.8   61.00    61.80    62.50
# table  26967.0    57.456080     2.232068   49.0   56.00    57.00    59.00
# x      26967.0     5.729854     1.128516    0.0    4.71     5.69     6.55
# y      26967.0     5.733569     1.166058    0.0    4.71     5.71     6.54
# z      26967.0     3.538057     0.720624    0.0    2.90     3.52     4.04
# price  26967.0  3939.518115  4024.864666  326.0  945.00  2375.00  5360.00
#
#             max
# carat      4.50
# depth     73.60
# table     79.00
# x         10.23
# y         58.90
# z         31.80
# price  18818.00

# %% [markdown]
# #### DATA VISUALIZATION

# %%
cut_price = df.groupby(['cut'])['price'].sum()
cut_price.plot.pie(title='Pie plot of cut vs price',
                   autopct='%1.1f%%', startangle=90, explode=[0, 0.1, 0, 0, 0], legend=True);

# %%
clarity_price = df.groupby(['clarity'])['price'].sum()
clarity_price.plot.pie(title='Pie plot of clarity vs price',
                   autopct='%1.1f%%', startangle=90,legend=True,figsize=(5,5));

# %%
cut_price = df.groupby(['color'])['price'].sum()
cut_price.plot.pie(title='Pie plot of color vs price',
                   autopct='%1.1f%%', startangle=90,legend=True,explode=[0, 0, 0, 0.1,0,0,0],figsize=(5,5));

# %%
k.dist_plot(df);
# Out:
# Large dataset detected, using 10000 random samples for the plots. Summary statistics are still based on the entire dataset.

# %%
df.cut.unique()
# Out:
# array(['Ideal', 'Premium', 'Very Good', 'Good', 'Fair'], dtype=object)

# %% [markdown]
# ### changing catagorical data to numerical

# %%
le=LabelEncoder()

# %%
df["cut"]=le.fit_transform(df.cut)

# %%
df["color"]=le.fit_transform(df.color)
df["clarity"]=le.fit_transform(df.clarity)

# %%
df
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z  price
# 0       0.30    2      1        2   62.1   58.0  4.27  4.29  2.66    499
# 1       0.33    3      3        1   60.8   58.0  4.42  4.46  2.70    984
# 2       0.90    4      1        7   62.2   60.0  6.04  6.12  3.78   6289
# 3       0.42    2      2        4   61.6   56.0  4.82  4.80  2.96   1082
# 4       0.31    2      2        6   60.4   59.0  4.35  4.43  2.65    779
# ...      ...  ...    ...      ...    ...    ...   ...   ...   ...    ...
# 26962   1.11    3      3        2   62.3   58.0  6.61  6.52  4.09   5408
# 26963   0.33    2      4        1   61.9   55.0  4.44  4.42  2.74   1114
# 26964   0.51    3      1        5   61.7   58.0  5.12  5.15  3.17   1656
# 26965   0.27    4      2        7   61.8   56.0  4.19  4.20  2.60    682
# 26966   1.25    3      6        2   62.0   58.0  6.90  6.88  4.27   5166
#
# [26967 rows x 10 columns]

# %% [markdown]
# ### KDA PLOT

# %%
for i in df.columns:
    if df[i].dtype != "object":
        sns.kdeplot(x=df[i],color="GREEN")
        plt.show();

# %% [markdown]
#   ### HISTOGRAM

# %%
for i in df.columns:
    if df[i].dtype != "object":
        sns.histplot(x=df[i],color="GREEN")
        plt.show();

# %% [markdown]
# ### HEATMAP

# %%
k.corr_plot(data=df,target="price");

# %%
k.clean_column_names(df)
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z  price
# 0       0.30    2      1        2   62.1   58.0  4.27  4.29  2.66    499
# 1       0.33    3      3        1   60.8   58.0  4.42  4.46  2.70    984
# 2       0.90    4      1        7   62.2   60.0  6.04  6.12  3.78   6289
# 3       0.42    2      2        4   61.6   56.0  4.82  4.80  2.96   1082
# 4       0.31    2      2        6   60.4   59.0  4.35  4.43  2.65    779
# ...      ...  ...    ...      ...    ...    ...   ...   ...   ...    ...
# 26962   1.11    3      3        2   62.3   58.0  6.61  6.52  4.09   5408
# 26963   0.33    2      4        1   61.9   55.0  4.44  4.42  2.74   1114
# 26964   0.51    3      1        5   61.7   58.0  5.12  5.15  3.17   1656
# 26965   0.27    4      2        7   61.8   56.0  4.19  4.20  2.60    682
# 26966   1.25    3      6        2   62.0   58.0  6.90  6.88  4.27   5166
#
# [26967 rows x 10 columns]

# %% [markdown]
# ### boxplot

# %%
for i in df.columns:
    if df[i].dtype!="object":
            sns.boxplot(y=df[i],color="red")
            plt.show()

# %% [markdown]
# ### cleaning the outliers

# %%
def outlier(col):
    Q3, Q1= np.nanpercentile(col,[75,25])
    iqr=Q3-Q1
    ul=Q3+1.5*iqr
    ll=Q1-1.5*iqr
    return ul, ll

# %%
for column in df.columns:
    if df[column].dtype !="object":
        ul,ll=outlier(df[column])
        df[column]=np.where((df[column]>ul)|(df[column]<ll),np.nan,df[column])

# %%
for i in df.columns:
    if df[i].dtype !="object":
        sns.boxplot(y=df[i],color="green")
        plt.show()

# %%
df.dropna(inplace=True)

# %% [markdown]
# ### REGRESSION

# %%
df
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z   price
# 0       0.30  2.0    1.0      2.0   62.1   58.0  4.27  4.29  2.66   499.0
# 1       0.33  3.0    3.0      1.0   60.8   58.0  4.42  4.46  2.70   984.0
# 2       0.90  4.0    1.0      7.0   62.2   60.0  6.04  6.12  3.78  6289.0
# 3       0.42  2.0    2.0      4.0   61.6   56.0  4.82  4.80  2.96  1082.0
# 4       0.31  2.0    2.0      6.0   60.4   59.0  4.35  4.43  2.65   779.0
# ...      ...  ...    ...      ...    ...    ...   ...   ...   ...     ...
# 26962   1.11  3.0    3.0      2.0   62.3   58.0  6.61  6.52  4.09  5408.0
# 26963   0.33  2.0    4.0      1.0   61.9   55.0  4.44  4.42  2.74  1114.0
# 26964   0.51  3.0    1.0      5.0   61.7   58.0  5.12  5.15  3.17  1656.0
# 26965   0.27  4.0    2.0      7.0   61.8   56.0  4.19  4.20  2.60   682.0
# 26966   1.25  3.0    6.0      2.0   62.0   58.0  6.90  6.88  4.27  5166.0
#
# [23022 rows x 10 columns]

# %%
x=df[["carat","cut","color","depth","table","x","y","z"]].values

# %%
y=df[["price"]].values

# %%
sc=StandardScaler()

# %%
x=sc.fit_transform(x)

# %% [markdown]
# ### CROSS VALIDATION

# %%
models = {
    "LinearRegression": LinearRegression(),
    "Lasso":Lasso(),
    "Ridge":Ridge(),
    "DecisionTreeRegressor":DecisionTreeRegressor(),
    "RandomForestRegressor":RandomForestRegressor()
}

# %%
for name, model in models.items():
    scores = cross_val_score(model, x,y, scoring="neg_mean_squared_error",cv=10,n_jobs=-1)
    print("cross validation model : {}".format(name))
    rmse = np.sqrt(-scores)
    rmse_average = np.mean(rmse)
    print("AVERAGE RMSE: ",rmse_average)
    print("*"*100)
# Out:
# cross validation model : LinearRegression
# AVERAGE RMSE:  997.2768554031314
# ****************************************************************************************************
# cross validation model : Lasso
# AVERAGE RMSE:  997.768017742754
# ****************************************************************************************************
# cross validation model : Ridge
# AVERAGE RMSE:  997.2476833848201
# ****************************************************************************************************
# cross validation model : DecisionTreeRegressor
# AVERAGE RMSE:  1197.2523308099717
# ****************************************************************************************************
# cross validation model : RandomForestRegressor
# AVERAGE RMSE:  875.4760507928728
# ****************************************************************************************************

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
models={
    "linearregression":LinearRegression(),
    "ridge":Ridge(),
    "lasso":Lasso(),
    "decisiontreeregressor":DecisionTreeRegressor(),
    "randomforestregressor":RandomForestRegressor(random_state=0)
}

# %%
for name,model in models.items():
    model.fit(x_train,y_train)
    print("model trained with {}".format(name))
    training_score =model.score(x_train,y_train)*100
    testing_score =model.score(x_test,y_test)*100
    score =r2_score(y_test,model.predict(x_test))*100
    mae = mean_absolute_error(y_test, model.predict(x_test))
    mse= mean_squared_error(y_test,model.predict(x_test))
    rmse= np.sqrt(mse)
    print("r2score: ",score)
    print("training_score:",training_score)
    print("testing_score:",testing_score)
    print("mae:",mae)
    print("mse:",mse)
    print("rmse_test:",rmse)
    print("   "*105)
# Out:
# model trained with linearregression
# r2score:  87.21819025858233
# training_score: 87.13754271479954
# testing_score: 87.21819025858233
# mae: 630.1868912303389
# mse: 978655.0029251018
# rmse_test: 989.26993430767
#
# model trained with ridge
# r2score:  87.21668416809067
# training_score: 87.13736632838867
# testing_score: 87.21668416809067
# mae: 630.3098906005876
# mse: 978770.3185982616
# rmse_test: 989.3282158102343
#
# model trained with lasso
# r2score:  87.1739842137286
# training_score: 87.11672118206654
# testing_score: 87.1739842137286
# mae: 630.8519773071605
# mse: 982039.6931865638
# rmse_test: 990.9791588053523
#
# model trained with decisiontreeregressor
# r2score:  79.94417465151085
# training_score: 99.98490825922435
# testing_score: 79.94417465151085
# mae: 675.8752442996743
# mse: 1535598.965418024
# rmse_test: 1239.192868530974
#
# model trained with randomforestregressor
# r2score:  90.16460340855029
# training_score: 98.57522844987912
# testing_score: 90.16460340855029
# mae: 499.87315047308823
# mse: 753059.2517571899
# rmse_test: 867.7898661295774

# %% [markdown]
# ### model training

# %%
model=RandomForestRegressor()

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
#  ### PRICE PREDICTION

# %%
y_pred = model.predict(x)

# %%
op=pd.DataFrame(zip(y,y_pred),columns=("ACTUAL","PREDICTED"),dtype=float)

# %% [markdown]
# ### scatterplot

# %%
plt.figure(figsize=(10,6))
plt.xticks()
sns.scatterplot(data=op,x='ACTUAL',y="PREDICTED")
plt.show();

# %% [markdown]
# ### LINE PLOT

# %%
plt.figure(figsize=(10,6))
plt.xticks()
sns.lineplot(data=op,x='ACTUAL',y="PREDICTED")
plt.show();
